# %%
import numpy as np
import pandas as pd

# %%
varus_original = pd.read_excel('varus.xlsx')

# %%
varus_original
# Out:
#       Study ID  Laterality (Right =1; Left = 2) Team Member Med Hist Review  \
# 0            7                              2.0                     Hailley
# 1           15                              2.0                     Hailley
# 2           17                              1.0                     Hailley
# 3           22                              2.0                     Hailley
# 4           29                              1.0                     Hailley
# ...        ...                              ...                         ...
# 1059      1120                              NaN                         NaN
# 1060      1121                              NaN                         NaN
# 1061      1122                              NaN                         NaN
# 1062      1123                              NaN                         NaN
# 1063      1124                              NaN                         NaN
#
# ...

# %%
varus_outliers = varus_original[(abs(varus_original['PreOp Mechanical axis']) >= 10) |
                                (abs(varus_original['Nav PreOp Measurement (degree; Valgus is negative)']) >= 10)]

# %%
varus_outliers
# Out:
#      Study ID  Laterality (Right =1; Left = 2) Team Member Med Hist Review  \
# 0           7                              2.0                     Hailley
# 1          15                              2.0                     Hailley
# 2          17                              1.0                     Hailley
# 3          22                              2.0                     Hailley
# 4          29                              1.0                     Hailley
# ..        ...                              ...                         ...
# 101         1                              1.0                      Andrey
# 102         2                              1.0                     Andrey
# 108         9                              2.0                      Andrey
# 315       308                              1.0                      Andrey
# 380       389                              1.0                         NaN
#
#     Team Member XRay Review  Meets Inclusion: (Y=1; N=2)  \
# ...
